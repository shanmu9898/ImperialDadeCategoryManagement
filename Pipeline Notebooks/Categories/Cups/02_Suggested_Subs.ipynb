# %% [markdown]
# # Generating Subs

# %% [markdown]
# #### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from openai_api import OpenAIAgent
import nest_asyncio
nest_asyncio.apply()
import os
import sys

# Add the parent directory (or another appropriate path) to sys.path so Python can find Exclusion_functions
notebook_dir = os.path.dirname(os.path.abspath('04_Optimization.ipynb'))
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..', '..', '..'))
function_dir = os.path.abspath(os.path.join(parent_dir, 'Function_Files'))
if function_dir not in sys.path:
    sys.path.append(function_dir)
    
import Matching_functions as mf
import datetime

# %% [markdown]
# #### Variables

# %%
CATEGORY = "Cups"
today = datetime.datetime.now().strftime('%m.%d.%Y')
ip_path = f"{parent_dir}\\Data\\"
ip_path_cat = f"{parent_dir}\\Data\\{CATEGORY}\\"
OP_PATH = f"{parent_dir}\\Data\\{CATEGORY}\\Output\\"

# %%
im_final = pd.read_csv(f"{OP_PATH}{CATEGORY}_Attributed.csv")

# %% [markdown]
# #### Embeddings and Matches

# %%
im_final = mf.make_embeddings(im_final)
# Out:
# Starting make_embeddings...
# Rows prepared for embedding: 4481
# Embedding Batches: 100%|██████████| 45/45 [00:32<00:00,  1.40it/s]
# Finished embedding generation.

# %%
user_prompts, idx_map = mf.get_user_prompts(im_final)
# Out:
# Generating Prompts: 100%|██████████| 4481/4481 [00:17<00:00, 262.39it/s]

# %%
count = 0
for user_prompt in user_prompts:
    count += 1
    print(user_prompt)
    print('----'*40)
    if count == 3:
        break
# Out:
# Original Item:
# - Entity ID: 1
#
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White|Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.7X6.1X2.4 IN, Cup Foam 20 Oz Tall Coca Cola Stock Print
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White|Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.7X6.1X2.4 IN.
# - Case Pack: 500
#
# Top Similar Items from Descriptions:
#
# - Entity ID: 751
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.8,  Product Dimensions: 3.6X6.8X2.4 IN, Cup Foam 20 Oz Cafe G Stock Print 3.6 In Dia
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.8
# - Product Dimensions: 3.6X6.8X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 737
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.7X6.1X2.4 IN, Cup Wht Foam 20 Oz Dart 3.7 In Dia 6 In Ht White
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.7X6.1X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 3468
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: Blue,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.7X6.1X2.4 IN, Cup-Foam 20 Oz Dart 20J16H 500 Horizon Blueberry 081184
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: Blue
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.7X6.1X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 860
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.9,  Product Dimensions: 3.7X6.9X2.6 IN, Cup Wht Foam 24 Oz Dart 3.7 In Dia 7 In Ht White
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.9
# - Product Dimensions: 3.7X6.9X2.6 IN.
# - Case Pack: 500
#
# - Entity ID: 749
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: Multicolor,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Hot Only,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.9,  Product Dimensions: 3.7X5.9X2.4 IN, Cup Foam 20 Oz Fusion Escape Stock Print
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: Multicolor
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Hot Only
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.9
# - Product Dimensions: 3.7X5.9X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 863
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.9,  Product Dimensions: 3.9X6.9X2.4 IN, Cup Wht Foam 24 Oz Tall Dart 4 In Dia 7 In Ht White
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.9
# - Product Dimensions: 3.9X6.9X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 1114
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.9,  Top Diameter (IN): 4.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.6,  Product Dimensions: 4.6X6.6X2.9 IN, Cup Wht Foam 32 Oz Dart 4.625 In Dia 6.625 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.9
# - Top Diameter (IN): 4.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.6
# - Product Dimensions: 4.6X6.6X2.9 IN.
# - Case Pack: 500
#
# - Entity ID: 869
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: Green,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 7.2,  Product Dimensions: 3.6X7.2X2.4 IN, Cup Foam 24 Oz Cafe G Stock Print Dart 3.6 In Dia
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: Green
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 7.2
# - Product Dimensions: 3.6X7.2X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 655
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 16 OZ,  Capacity Value 1: 16,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.4,  Product Dimensions: 3.7X5.4X2.4 IN, 16J16H 16 Oz Horizon Cranberry Prt Foam Cup 1M/Cs
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 16 OZ
# - Capacity Value 1: 16
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.4
# - Product Dimensions: 3.7X5.4X2.4 IN.
# - Case Pack: 1000
#
# - Entity ID: 652
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 16 OZ,  Capacity Value 1: 16,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.4,  Product Dimensions: 3.7X5.4X2.4 IN, Cup Wht Foam 16 Oz Dart 3.7 In Dia 5.4 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 16 OZ
# - Capacity Value 1: 16
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.4
# - Product Dimensions: 3.7X5.4X2.4 IN.
# - Case Pack: 1000
#
#
# Return a list of Entity IDs that are swappable with the given Entity ID from the list of similar items.
# If an item doesn't seem like it is swappable you can return None.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Original Item:
# - Entity ID: 2
#
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.5,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.9X6.1X2.5 IN, Cup Cold Clr Pp 24 Oz
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.5
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.9X6.1X2.5 IN.
# - Case Pack: 600
#
# Top Similar Items from Descriptions:
#
# - Entity ID: 867
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.5,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.9X6.1X2.5 IN, Cup Cold Clr Pp 24 Oz
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.5
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.9X6.1X2.5 IN.
# - Case Pack: 600
#
# - Entity ID: 3444
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.5,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.0,  Product Dimensions: 3.9X6X2.5 IN, Cup Cold Clr Pp 24 Oz Nexclear
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.5
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.0
# - Product Dimensions: 3.9X6X2.5 IN.
# - Case Pack: 600
#
# - Entity ID: 744
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.4,  Product Dimensions: 3.9X5.4X2.4 IN, Cup Clr Pp 20 Oz (L24C) *See Nc20 *
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.4
# - Product Dimensions: 3.9X5.4X2.4 IN.
# - Case Pack: 600
#
# - Entity ID: 1844
# - Description: Baskin Robbins 24Oz Pp Cold Cup Clr 600
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes:
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN):
# - Top Diameter (IN):
# - Product Dimension Type:
# - Wall Height (IN):
# - Product Dimensions: .
# - Case Pack: 600
#
# - Entity ID: 1843
# - Description: Baskin Robbins 24Oz Pp Cold Cup Clr 600
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes:
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN):
# - Top Diameter (IN):
# - Product Dimension Type:
# - Wall Height (IN):
# - Product Dimensions: .
# - Case Pack: 600
#
# - Entity ID: 2281
# - Description: Daz Bog 24Oz Pp Cold Cup 600
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color:
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes:
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN):
# - Top Diameter (IN):
# - Product Dimension Type:
# - Wall Height (IN):
# - Product Dimensions:  .
# - Case Pack: 600
#
# - Entity ID: 666
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 16 OZ,  Capacity Value 1: 16,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 4.8,  Product Dimensions: 3.9X4.8X2.4 IN, Cup Cold Clr Pp 16 Oz Conex
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 16 OZ
# - Capacity Value 1: 16
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 4.8
# - Product Dimensions: 3.9X4.8X2.4 IN.
# - Case Pack: 1000
#
# - Entity ID: 3082
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polyethylene Terephthalate (PET),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.5,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.9X6.1X2.5 IN, Cup Cold 24 Oz Clr Pet Use Lid Lkc16/24  Sub=Td24
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polyethylene Terephthalate (PET)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.5
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.9X6.1X2.5 IN.
# - Case Pack: 600
#
# - Entity ID: 3921
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 600/Case,  Color: Clear,  Material: Polyethylene Terephthalate (PET),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 24 OZ,  Capacity Value 1: 24,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.0,  Product Dimensions: 3.9X6X2.6 IN, Cup Cold Clr Pet 24 Oz Solo Ultra 4 In Dia 6 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 600/Case
# - Color: Clear
# - Material: Polyethylene Terephthalate (PET)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 24 OZ
# - Capacity Value 1: 24
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.0
# - Product Dimensions: 3.9X6X2.6 IN.
# - Case Pack: 600
#
# - Entity ID: 3443
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Clear,  Material: Polypropylene (PP),  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold Only,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.9,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.5,  Product Dimensions: 3.9X5.5X2.4 IN, Cup Cold Clr Pp 20 Oz Nc20
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Clear
# - Material: Polypropylene (PP)
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold Only
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.9
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.5
# - Product Dimensions: 3.9X5.5X2.4 IN.
# - Case Pack: 1000
#
#
# Return a list of Entity IDs that are swappable with the given Entity ID from the list of similar items.
# If an item doesn't seem like it is swappable you can return None.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Original Item:
# - Entity ID: 3
#
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 400/Case,  Color: White|Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 4.2,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 7.1,  Product Dimensions: 4.2X7.1X2.6 IN, Cup Foam 32 Oz Coca-Cola
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 400/Case
# - Color: White|Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 4.2
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 7.1
# - Product Dimensions: 4.2X7.1X2.6 IN.
# - Case Pack: 400
#
# Top Similar Items from Descriptions:
#
# - Entity ID: 1095
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 400/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 4.2,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 7.1,  Product Dimensions: 4.2X7.1X2.6 IN, 32Aj20 Cup 32 Oz Foam Wht 400/Cs White
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 400/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 4.2
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 7.1
# - Product Dimensions: 4.2X7.1X2.6 IN.
# - Case Pack: 400
#
# - Entity ID: 1097
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 400/Case,  Color: Teal,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 4.2,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 7.1,  Product Dimensions: 4.2X7.1X2.6 IN, Cup Foam 32 Oz Horizon Stock Print 4.2 In Dia 7 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 400/Case
# - Color: Teal
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 4.2
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 7.1
# - Product Dimensions: 4.2X7.1X2.6 IN.
# - Case Pack: 400
#
# - Entity ID: 1114
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.9,  Top Diameter (IN): 4.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.6,  Product Dimensions: 4.6X6.6X2.9 IN, Cup Wht Foam 32 Oz Dart 4.625 In Dia 6.625 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.9
# - Top Diameter (IN): 4.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.6
# - Product Dimensions: 4.6X6.6X2.9 IN.
# - Case Pack: 500
#
# - Entity ID: 1
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 500/Case,  Color: White|Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 20 OZ,  Capacity Value 1: 20,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 6.1,  Product Dimensions: 3.7X6.1X2.4 IN, Cup Foam 20 Oz Tall Coca Cola Stock Print
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 500/Case
# - Color: White|Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 20 OZ
# - Capacity Value 1: 20
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 6.1
# - Product Dimensions: 3.7X6.1X2.4 IN.
# - Case Pack: 500
#
# - Entity ID: 655
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 16 OZ,  Capacity Value 1: 16,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.4,  Product Dimensions: 3.7X5.4X2.4 IN, 16J16H 16 Oz Horizon Cranberry Prt Foam Cup 1M/Cs
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 16 OZ
# - Capacity Value 1: 16
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.4
# - Product Dimensions: 3.7X5.4X2.4 IN.
# - Case Pack: 1000
#
# - Entity ID: 1093
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 400/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Product Capacity: 32 OZ,  Capacity Value 1: 32,  Capacity Preferred Metric 1: Ounce (OZ), 32Ab32 32 Oz Foam Car Cup 400/Cs
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 400/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature:
# - Beverage Cup Style:
# - Sustainable Products:
# - Product Capacity: 32 OZ
# - Capacity Value 1: 32
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN):
# - Top Diameter (IN):
# - Product Dimension Type:
# - Wall Height (IN):
# - Product Dimensions: .
# - Case Pack: 400
#
# - Entity ID: 1289
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 300/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 44 OZ,  Capacity Value 1: 44,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.6,  Top Diameter (IN): 4.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 8.4,  Product Dimensions: 4.6X8.4X2.6 IN, Cup Foam 44 Oz Plain Wht Pedestal Form White
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 300/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 44 OZ
# - Capacity Value 1: 44
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.6
# - Top Diameter (IN): 4.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 8.4
# - Product Dimensions: 4.6X8.4X2.6 IN.
# - Case Pack: 300
#
# - Entity ID: 652
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: White,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 16 OZ,  Capacity Value 1: 16,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.4,  Top Diameter (IN): 3.7,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 5.4,  Product Dimensions: 3.7X5.4X2.4 IN, Cup Wht Foam 16 Oz Dart 3.7 In Dia 5.4 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: White
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 16 OZ
# - Capacity Value 1: 16
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.4
# - Top Diameter (IN): 3.7
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 5.4
# - Product Dimensions: 3.7X5.4X2.4 IN.
# - Case Pack: 1000
#
# - Entity ID: 550
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 12 OZ,  Capacity Value 1: 12,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.1,  Top Diameter (IN): 3.6,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 4.0,  Product Dimensions: 3.6X4X2.1 IN, Cup Foam 12 Oz Squat Cafe G Stock Print 3.6 In Dia 4 In Ht
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 12 OZ
# - Capacity Value 1: 12
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.1
# - Top Diameter (IN): 3.6
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 4.0
# - Product Dimensions: 3.6X4X2.1 IN.
# - Case Pack: 1000
#
# - Entity ID: 549
# - Description: Beverage Cup Type: Cup,  Product Type Collapse: Cup,  Pack Size: 1000/Case,  Color: Red,  Material: Polystyrene Foam,  Foodservice Global Attributes: Disposable,  Usage Temperature: Cold & Hot,  Beverage Cup Style: Insulated,  Product Capacity: 12 OZ,  Capacity Value 1: 12,  Capacity Preferred Metric 1: Ounce (OZ),  Bottom Diameter (IN): 2.1,  Top Diameter (IN): 3.5,  Product Dimension Type: Tapered & Graduated Product Dimensions,  Wall Height (IN): 4.4,  Product Dimensions: 3.5X4.4X2.1 IN, Cup Hot Foam 12 Oz Cafe G Stock Print 3.5 In Dia
# - Beverage Cup Type: Cup
# - Product Type Collapse: Cup
# - Pack Size: 1000/Case
# - Color: Red
# - Material: Polystyrene Foam
# - Foodservice Global Attributes: Disposable
# - Usage Temperature: Cold & Hot
# - Beverage Cup Style: Insulated
# - Sustainable Products:
# - Product Capacity: 12 OZ
# - Capacity Value 1: 12
# - Capacity Preferred Metric 1: Ounce (OZ)
# - Lid, Cover & Cap Type:
# - Lid, Cover & Cap Style:
# - Compatible Product & Product Type:
# - Bottom Diameter (IN): 2.1
# - Top Diameter (IN): 3.5
# - Product Dimension Type: Tapered & Graduated Product Dimensions
# - Wall Height (IN): 4.4
# - Product Dimensions: 3.5X4.4X2.1 IN.
# - Case Pack: 1000
#
#
# Return a list of Entity IDs that are swappable with the given Entity ID from the list of similar items.
# If an item doesn't seem like it is swappable you can return None.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(len(user_prompts))
# Out:
# 4481

# %%
im_final = mf.generate_matches(im_final, user_prompts, idx_map, batch_model = False)
# Out:
# Initializing OpenAI agent with model: gpt-4o
# Getting responses from API (batch=False)...
# Running cost $38.3604: 100%|██████████| 141/141 [1:42:59<00:00, 43.82s/chunk]
# Received 4481 responses
# Warning: Cannot convert match ID 'None' to integer in response 1167. Skipping match.
# Warning: Cannot convert match ID 'None' to integer in response 3885. Skipping match.
# Error decoding JSON response 4043: Unterminated string starting at: line 4 column 16 (char 70)
# Response preview: {
#   "Entity ID": 4044,
#   "Matches": [4036, 755, 2078],
#   "reasoning": "The original item (Entity ID: 4044) is a 16 OZ double-wall poly-coated paper cup with a kraft color, designed for hot beverages, ...
# Warning: Cannot convert match ID 'None' to integer in response 4363. Skipping match.
# Finished processing matches.

# %%
im_final.head()
# Out:
#   Entity--Item                    Item Desc 1               Item Desc 2  \
# 0   1--.20J16C  Cup Foam 20 Oz Tall Coca Cola               Stock Print
# 1      1--.24P          Cup Cold Clr Pp 24 Oz                       NaN
# 2  1--.32AJ20C       Cup Foam 32 Oz Coca-Cola                       NaN
# 3    1--.374MS     4 Oz Mistique Design Paper                   Hot Cup
# 4       1--.5C          Cup Cold Clr Pet 5 Oz  Solo Ultra Use Lid L7N25
#
#      Qty  Gross Cost  Net Cost  po_cost_amt VB Flag   VGN         VPN  ...  \
# 0   43.0        1768      1768    41.070233       N  Dart      20J16C  ...
# 1   28.0        1219      1103    44.790000       N  Dart        24PX  ...
# 2    9.0         645       645    71.720000       N  Dart     32AJ20C  ...
# 3   40.0        1677      1677    41.590000       N  Dart  374MS-0029  ...
# 4  102.0       13368     12798   127.164608       N  Dart          5C  ...
#
#   Bottom Diameter (IN) Top Diameter (IN)  \
# 0                  2.4               3.7
# 1                  2.5               3.9
# 2                  2.6               4.2
# 3                  1.8               2.5
# 4                  NaN               NaN
#
#                    Product Dimension Type Wall Height (IN) Product Dimensions  \
# 0  Tapered & Graduated Product Dimensions              6.1    3.7X6.1X2.4 IN.
# 1  Tapered & Graduated Product Dimensions              6.1    3.9X6.1X2.5 IN.
# 2  Tapered & Graduated Product Dimensions              7.1    4.2X7.1X2.6 IN.
# 3  Tapered & Graduated Product Dimensions              2.4    2.5X2.4X1.8 IN.
# 4                                     NaN              NaN                  .
#
#   Case Pack                                      for_embedding  \
# 0     500.0  Cup Cup 500/Case White|Red Polystyrene Foam Di...
# 1     600.0  Cup Cup 600/Case Clear Polypropylene (PP) Disp...
# 2     400.0  Cup Cup 400/Case White|Red Polystyrene Foam Di...
# 3    1000.0  Cup Cup 1000/Case  Single Wall Poly-Coated Pap...
# 4    2500.0  Cup Cup 2500/Case    Cold Only   5 OZ 5 Ounce ...
#
#                                           embeddings  \
# 0  [-0.03733288496732712, -0.012603497132658958, ...
# 1  [-0.035604093223810196, 0.017317011952400208, ...
# 2  [-0.0315215140581131, -0.00047575688222423196,...
# 3  [-0.008562684990465641, 0.023839062079787254, ...
# 4  [-0.021733123809099197, 0.007190897595137358, ...
#
#                                              Matches  \
# 0                             [1--20J16, 1--P081184]
# 1                                 [1--24PX, 1--NC24]
# 2                            [1--32AJ20, 1--32AJ20H]
# 3                  [1--374SI, 1--374W-2050, 1--SMR4]
# 4  [5--501-29, 1--VBPP5CUP, 2--037397, 4--WEB-500...
#
#                                            reasoning
# 0  The items with Entity IDs 737 and 3468 are swa...
# 1  The items with Entity IDs 867 and 3444 are swa...
# 2  The items with Entity IDs 1095 and 1097 are sw...
# 3  The items with Entity IDs 1211, 1213, and 3838...
# 4  The original item has specific attributes such...
#
# [5 rows x 38 columns]

# %% [markdown]
# #### Write Matches Data

# %%
im_final.to_csv(f"{OP_PATH}{CATEGORY}_matches.csv", index=False)

# %%
im_final = pd.read_csv(f"{OP_PATH}{CATEGORY}_matches.csv")

# %% [markdown]
# #### Output Subs report

# %%
mf.write_top_matches(im_final, f"{OP_PATH}{CATEGORY}_Subs_{today}.xlsx", n = 20, pl = True, enable_vpn_exclusion = True)
# Out:
# Starting write_top_matches with enable_vpn_exclusion=True
# Looking for qty column: 'Qty'
# Available columns: ['Entity--Item', 'Item Desc 1', 'Item Desc 2', 'Qty', 'Gross Cost', 'Net Cost', 'po_cost_amt', 'VB Flag', 'VGN', 'VPN', 'Pack Size', 'Combined Descriptions', 'Description with Attributes', 'attributes', 'Beverage Cup Type', 'Product Type Collapse', 'Color', 'Material', 'Foodservice Global Attributes', 'Usage Temperature', 'Beverage Cup Style', 'Sustainable Products', 'Product Capacity', 'Capacity Value 1', 'Capacity Preferred Metric 1', 'Lid, Cover & Cap Type', 'Lid, Cover & Cap Style', 'Compatible Product & Product Type', 'Bottom Diameter (IN)', 'Top Diameter (IN)', 'Product Dimension Type', 'Wall Height (IN)', 'Product Dimensions', 'Case Pack', 'for_embedding', 'embeddings', 'Matches', 'reasoning', 'description_display_col']
# Found qty column 'Qty' with 4481 rows
# Qty column is numeric, sorting by Qty
# PL filter applied: 440 rows remain
# Selected top 20 items
# Processed target item: 1--VG16CF with 2 substitutes
# Processed target item: 1--F98HCF with 4 substitutes
# Processed target item: 1--VBCLHP12W with 6 substitutes
# Processed target item: 1--VG12CF with 3 substitutes
# Processed target item: 1--VBCLLH16DW with 3 substitutes
# Processed target item: 1--PTC09D92 with 1 substitutes
# Skipping match 6--VG24CF due to VPN matching conditions
# Processed target item: 1--VG24CF with 5 substitutes
# Processed target item: 1--CC with 4 substitutes
# Processed target item: 1--VBCLLH16DB with 2 substitutes
# Processed target item: 1--VBCLHP10SW with 8 substitutes
# Processed target item: 1--VG20CF with 3 substitutes
# Processed target item: 1--7OZ22GRAM with 3 substitutes
# Processed target item: 1--D8PCRKR with 2 substitutes
# Processed target item: 1--VB98SL with 2 substitutes
# Skipping match 6--561004600 due to VPN matching conditions
# Processed target item: 1--VBCLHP8W with 7 substitutes
# Skipping match 5--VBCLHP16W-2 due to VPN matching conditions
# Processed target item: 1--VBCLHP16W with 6 substitutes
# Processed target item: 1--VBPP7CUP with 2 substitutes
# Processed target item: 1--VBBC4CK with 3 substitutes
# Processed target item: 1--VG10CF with 3 substitutes
# Skipping match 4--VB-CLH8W due to VPN matching conditions
# Processed target item: 1--VBCLH8W with 6 substitutes
# Excel report successfully created: C:\Users\MGadupudi\PycharmProjects\ImperialDadeCategoryManagement\Data\Cups\Output\Cups_Subs_09.30.2025.xlsx
